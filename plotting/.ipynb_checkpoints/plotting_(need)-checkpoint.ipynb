# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %%
conda install matplotlib -c conda-forge
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 24.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
from matplotlib import pyplot as plt

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\zawht\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-package-handling-2.2.0|   py39haa95532_0         287 KB
#     conda-package-streaming-0.9.0|   py39haa95532_0          29 KB
#     zstandard-0.19.0           |   py39h2bbff1b_0         340 KB
#     ------------------------------------------------------------
#                                            Total:         655 KB
#
# The following NEW packages will be INSTALLED:
#
#   conda-package-str~ pkgs/main/win-64::conda-package-streaming-0.9.0-py39haa95532_0 None
#   zstandard          pkgs/main/win-64::zstandard-0.19.0-py39h2bbff1b_0 None
#
# The following packages will be UPDATED:
#
#   conda-package-han~                   1.9.0-py39h8cc25b3_0 --> 2.2.0-py39haa95532_0 None
#
#
#
# Downloading and Extracting Packages
#
# conda-package-handli | 287 KB    |            |   0%
# conda-package-handli | 287 KB    | ########3  |  84%
# conda-package-handli | 287 KB    | ########## | 100%
#
# conda-package-stream | 29 KB     |            |   0%
# conda-package-stream | 29 KB     | ########## | 100%
# conda-package-stream | 29 KB     | ########## | 100%
#
# zstandard-0.19.0     | 340 KB    |            |   0%
# zstandard-0.19.0     | 340 KB    | ########## | 100%
# zstandard-0.19.0     | 340 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 24.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')                                  #Labels the x-axis
plt.ylabel('y-values')                                  #Labels the y-axis
plt.title('X vs Y')                                     #Title of graph
plt.grid(alpha=.25)
plt.legend(loc='upper left')                            #Location of legend

# %%
# Some data for plotting
x = [0, 2, 4, 6, 8, 10, 12]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')                                  #Labels the x-axis
plt.ylabel('y-values')                                  #Labels the y-axis
plt.title('X vs Y')                                     #Title of graph
plt.grid(alpha=.25)
plt.legend(loc='upper right')                            #Location of legend

# %%
# Some data for plotting
x = [0, 2, 4, 6, 8, 10, 12]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_2, label='Y values',
         c='green', ls='solid', lw=0.25)              #plots graph of y_2 against x
plt.xlabel('x-values')                                  #Labels the x-axis
plt.ylabel('y-value')                                  #Labels the y-axis
plt.title('X vs Y')                                     #Title of graph
plt.grid(alpha=1)                                       #Opacity of grid line (values from 0 - 1)
plt.legend(loc='upper right')                           #Location of legend

# %% [markdown]
# ### Things to note

# %%
# Some data for plotting
x = [0, 2, 4, 6, 8, 10, 12]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, y_2, label='Y values',
         c='green', ls='solid', lw=3)              #plots graph of y_2 against x
plt.xlabel('x-values')                                  #Labels the x-axis
plt.ylabel('y-value')                                  #Labels the y-axis
plt.title('X vs Y')                                     #Title of graph
plt.grid(alpha=1)                                       #Opacity of grid line (values from 0 - 1)
plt.legend(loc='upper right')                           #Location of legend

# %% [markdown]
# ## 1.2 Adding another plot

# %%
# Some data for plotting
x = [0, 2, 4, 6, 8, 10, 12]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y1 values',
         c='green', ls='solid', lw=1)              #plots graph of y_2 against x
plt.plot(x, y_2, label='Y2 values',
         c='orange', ls='dashed', lw=1)
plt.xlabel('x-values')                                  #Labels the x-axis
plt.ylabel('y-value')                                   #Labels the y-axis
plt.title('X vs Y')                                     #Title of graph
plt.grid(alpha=1)                                       #Opacity of grid line (values from 0 - 1)
plt.legend(loc='upper right')                           #Location of legend

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# %%
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error = [0.1, 0.35, 0.45, 0.2, 0.5, 0.75, 0.3]
y_error = [0.25, 0.3, 0.5, 0.25, 0.4, 0.6, 0.75]

plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.grid(alpha=.25)
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2
plt.grid(alpha=.25)

# %% [markdown]
# ### Things to note

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2
plt.grid(alpha=.25)

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows = 24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha = 0.5)
plt.ylim([-8, 8])
# Out:
# (-8.0, 8.0)

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows = 24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha = 0.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('ggplot')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows = 24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha = 0.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ### xkcd!

# %%
plt.xkcd()

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows = 24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha = 0.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows = 24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha = 0.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')
